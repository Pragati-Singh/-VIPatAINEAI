# %%
import random
Player_name = input("Enter your name : ")
moves = ["ROCK", "PAPER", "SCISSORS", "LIZARD", "SPOCK"] 
for i in range(len(moves)):
  # taking random moves for computer by using random.choice library
  computer_choice = random.choice(moves)
  computer_choice = computer_choice.upper()
  # print("Computer's move is : {} ".format(computer_choice))
  # Taking user choice or input and capitalizing to avoid syntax error
  user_choice = input("Enter your move ( ROCK, PAPER, SCISSORS, LIZARD, SPOCK) or 'q' for quit : ")
  user_choice = user_choice.upper()
    # using Nested If loop
  if user_choice in moves:
      player_moves = user_choice
  elif user_choice not in moves:
      print("invalid choice")
      break

  def winner(computer_move, player_move):


      if player_move == moves[0]:

          if computer_move == moves[0]:
              print("There is a tie.")

          elif computer_move == moves[1]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Paper Cover Rock")
              print("Computer won")

          elif computer_move == moves[2]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Rock crushes Scissors")
              print("{} won ".format(Player_name))

          elif computer_move == moves[3]:
              print("Computer's move is : {} ".format(computer_choice))
              print(" Rock crushes Lizard")
              print("{} won ".format(Player_name))


          elif computer_move == moves[4]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Spock vaporizes Rocks")
              print("Computer won")


      elif player_move == moves[1]:

          if computer_move == moves[0]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Paper Cover Rock")
              print("{} won ".format(Player_name))            


          elif computer_move == moves[1]:
              print("There is a tie")


          elif computer_move == moves[2]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Scissors cuts Paper")
              print("Computer won")

          elif computer_move == moves[3]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Lizard eats Paper")
              print("Computer won")


          elif computer_move == moves[4]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Paper disproves Spock")
              print("{} won ".format(Player_name)) 


              
      elif player_move == moves[2]:

          if computer_move == moves[0]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Rock crushes Scissors")
              print("Computer won")           


          elif computer_move == moves[1]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Scissors cuts Paper")
              print("{} won ".format(Player_name))


          elif computer_move == moves[2]:
              print("There is a tie.")


          elif computer_move == moves[3]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Scissors decapitates Lizard")
              print("{} won ".format(Player_name)) 



          elif computer_move == moves[4]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Computer won")

      elif player_move == moves[3]:

          if computer_move == moves[0]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Rock crushes Lizard")
              print("Computer won")           


          elif computer_move == moves[1]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Lizard eats Paper")
              player_score += 1
              print("Player's score is: %s" %(player_score))
              print("{} won ".format(Player_name))


          elif computer_move == moves[2]:
              print("Scissors decapitates Lizard")
              print("Computer won")


          elif computer_move == moves[3]:
              print("There is a tie")


          elif computer_move == moves[4]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Lizard poisons Spock")
              print("{} won".format(Player_name))


      elif player_move == moves[4]:

          if computer_move == moves[0]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Spock vaporizes Rocks") 
              print("{} won".format(Player_name))


          elif computer_move == moves[1]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Paper disproves Spock")
              print("Computer won")



          elif computer_move == moves[2]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Spock smashes Scissors")
              print("{} won".format(Player_name))


          elif computer_move == moves[3]:
              print("Computer's move is : {} ".format(computer_choice))
              print("Lizard poisons Spock")
              print("Computer won")


          elif computer_move == moves[4]:
              # print("Computer's move is : {} ".format(computer_choice)
              print("There is a tie")

          
  #     begin = input("Do you want to continue? y = Yes, q = Quit :")
  #     begin = begin.lower()
  #     if begin == 'q':
  #         break
      
          
  winner(computer_choice, player_moves)
# Out:
# Enter your name : ps
# Enter your move ( ROCK, PAPER, SCISSORS, LIZARD, SPOCK) or 'q' for quit : spock
# Computer's move is : SCISSORS
# Spock smashes Scissors
# ps won
# Enter your move ( ROCK, PAPER, SCISSORS, LIZARD, SPOCK) or 'q' for quit : q
# invalid choice
