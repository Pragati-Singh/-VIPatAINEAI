# %% [markdown]
# ##                 Statistical Analysis and Hypothesis Testing

# %% [markdown]
# # PROJECT - Increasing YoY revenue from game purchases by increasing retention rate of gamers

# %% [markdown]
# ### Packages and setup

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os

from scipy.stats import shapiro
import scipy.stats as stats

#parameter settings
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Reading data and initial processing

# %%
#Read data using pandas
user_df=pd.read_csv("cookie_cats.csv")

#Check data types of each column using "dtypes" function
print("Data types for the data set:")
user_df.dtypes

#Check dimension of data i.e. # of rows and #column using pandas "shape" funtion
print("Shape of the data i.e. no. of rows and columns")
user_df.shape

#display first 5 rows of the data using "head" function
print("First 5 rows of the raw data:")
user_df.head()
# Out:
# Data types for the data set:
# userid             int64
# version           object
# sum_gamerounds     int64
# retention_1         bool
# retention_7         bool
# dtype: object
# Shape of the data i.e. no. of rows and columns
# (90189, 5)
# First 5 rows of the raw data:
#    userid  version  sum_gamerounds  retention_1  retention_7
# 0     116  gate_30               3        False        False
# 1     337  gate_30              38         True        False
# 2     377  gate_40             165         True        False
# 3     483  gate_40               1        False        False
# 4     488  gate_40             179         True         True

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ##  Detect and resolve problems in the data (Missing value, Outliers, etc.)

# %% [markdown]
# ### => Identify missing value

# %%
#Check for any missing values in the data using isnull() function
user_df.isnull().sum()
# Out:
# userid            0
# version           0
# sum_gamerounds    0
# retention_1       0
# retention_7       0
# dtype: int64

# %% [markdown]
# ### => Identify outliers

# %%
#Check for outlier values in sum_gamerounds column
plt.title("Total gamerounds played")
plt.xlabel("Index")
plt.ylabel("sum_gamerounds")
plt.plot(user_df.sum_gamerounds)
# Out:
# Text(0.5, 1.0, 'Total gamerounds played')
# Text(0.5, 0, 'Index')
# Text(0, 0.5, 'sum_gamerounds')

# %%
#Based on the plot, filter out the outlier from sum_gamerounds played; Use max() fucntion to find the index of the outlier

print("Maxm value of sum_gamerounds")
max_value = max(user_df.sum_gamerounds)
max_value

print("Index of the max value")
index_value = user_df[user_df.sum_gamerounds.isin([max_value])].index.tolist()
index_value

# remove the row by index

user_df.drop(user_df.index[index_value], inplace = True)

user_df
# Out:
# Maxm value of sum_gamerounds
# 2961
# Index of the max value
# [7912]
#         userid  version  sum_gamerounds  retention_1  retention_7
# 0          116  gate_30               3        False        False
# 1          337  gate_30              38         True        False
# 2          377  gate_40             165         True        False
# 3          483  gate_40               1        False        False
# 4          488  gate_40             179         True         True
# ...        ...      ...             ...          ...          ...
# 90184  9999441  gate_40              97         True        False
# 90185  9999479  gate_40              30        False        False
# 90186  9999710  gate_30              28         True        False
# 90187  9999768  gate_40              51         True        False
# 90188  9999861  gate_40              16        False        False
#
# [90187 rows x 5 columns]

# %%
# Plot the graph for sum_gamerounds player after removing the outlier
plt.title("Total rounds played")
plt.xlabel("Index")
plt.ylabel("sum_gamerounds")
plt.plot(user_df.sum_gamerounds)
# Out:
# Text(0.5, 1.0, 'Total rounds played')
# Text(0.5, 0, 'Index')
# Text(0, 0.5, 'sum_gamerounds')

# %% [markdown]
# ## Plot summary statistics and identify trends to answer basis business questions

# %% [markdown]
# ### Overall 7-day retention rate of the game

# %%
#Insert calculation for 7-day retention rate

retention_rate_7 = round((user_df.retention_7.sum()/user_df.shape[0])*100,2)

print("Overall 7 days retention rate of the game for both versions is: ", retention_rate_7,"%")
# Out:
# Overall 7 days retention rate of the game for both versions is:  18.61 %

# %% [markdown]
# ###  No. of players, who never played the game after installing

# %%
# Find number of customers with sum_gamerounds is equal to zero

user_df[user_df.sum_gamerounds == 0].shape[0]
# Out:
# 3994

# %% [markdown]
# ### Does the number of users decreases as the level progresses highlighting the difficulty of the game?

# %%
#Group by sum_gamerounds and count the number of users for the first 200 gamerounds
#Use plot() function on the summarized stats to visualize the chart

new_data  = user_df[["userid","sum_gamerounds"]].groupby("sum_gamerounds").count().reset_index().rename(columns = {"userid":"count"})[0:200]

plt.xlabel("sum_gamerounds")
plt.ylabel("count of players")

plt.title("Count of Player Vs sum_gamerouds")
plt.plot(new_data["sum_gamerounds"],new_data["count"])
# Out:
# Text(0.5, 0, 'sum_gamerounds')
# Text(0, 0.5, 'count of players')
# Text(0.5, 1.0, 'Count of Player Vs sum_gamerouds')

# %% [markdown]
# ## Generate crosstab for two groups of players to understand if there is a difference in 7 days retention rate & total number of game rounds played

# %% [markdown]
# ### Seven days retention rate summary for different game versions

# %%
#Create cross tab for game version and retention_7 flag counting number of users for each possible categories

pd.crosstab(user_df.version, user_df.retention_7).apply(lambda r: r/r.sum(), axis=1)
# Out:
# retention_7     False     True
# version
# gate_30      0.809835  0.190165
# gate_40      0.818000  0.182000

# %% [markdown]
# <mark>__Analsysis Results:__
# There is negligible difference among the two groups. In both the case, majority of the players(~ 80%) quit the game after 7 days period.

# %% [markdown]
# ### Gamerounds summary for different game versions

# %%
#use pandas group by to calculate average game rounds played summarized by different versions
user_df.groupby(['version']).agg({'sum_gamerounds': ['mean']})
# Out:
#         sum_gamerounds
#                   mean
# version
# gate_30      51.277015
# gate_40      51.298776

# %% [markdown]
# Do total number of gamerounds played in total by each player differ based on different versions of the game?
#
# <mark>__Analsysis Results:__
# There is not much difference in the total number of gamerounds of two different versions of the game played by each player.

# %% [markdown]
# ## Perform two-sample test for groups A and B to test statistical significance amongst the groups in the sum of game rounds played i.e., if groups A and B are statistically different

# %% [markdown]
# ### Initial data processing

# %%
#Define A/B groups for hypothesis testing
#user_df["version"] = np.where(user_df.version == "gate_30", "A", "B")

user_df["version"] = user_df["version"].replace(["gate_30","gate_40"],["A","B"])

group_A=pd.DataFrame(user_df[user_df.version=="A"]['sum_gamerounds'])
group_B=pd.DataFrame(user_df[user_df.version=="B"]['sum_gamerounds'])

# %% [markdown]
# ###  Shapiro test of Normality

# %%
#---------------------- Shapiro Test ----------------------
# NULL Hypothesis H0: Distribution is normal
# ALTERNATE Hypothesis H1: Distribution is not normal    

#test for group_A
stats.shapiro(group_A)


#test for group_B
stats.shapiro(group_B)
# Out:
# ShapiroResult(statistic=0.4946820139884949, pvalue=0.0)
# ShapiroResult(statistic=0.4825654625892639, pvalue=0.0)

# %% [markdown]
# Analyze and interpret the results of shapiro test of normality i.e. are the two groups normally distributed?
#
# <mark>__Analsysis Results:__
#
# __According to Shapiro test of Normality, Null hypothesis is rejected i.e, distribution is normal because p-value is less than 0.05.
# Yes Distribution is not normal H1 is accepted__

# %% [markdown]
# ### Test of homegienity of variance

# %%
#---------------------- Leven's Test ----------------------
# NULL Hypothesis H0: Two groups have equal variances
# ALTERNATE Hypothesis H1: Two groups do not have equal variances

#perform levene's test and accept or reject the null hypothesis based on the results

from scipy.stats import levene

levene(group_A.sum_gamerounds,group_B.sum_gamerounds)
# Out:
# LeveneResult(statistic=0.14043727235377643, pvalue=0.70784757202386)

# %% [markdown]
# <mark>__Analsysis Results:__
#
# __The p-value suggests that we fail to reject the null hypothesis, group A and B both have equal vairances.__

# %% [markdown]
# ### Test of significance: Two sample test

# %%
#---------------------- Two samples test ----------------------

#Apply relevant two sample test to accept or reject the NULL hypothesis

# NULL Hypothesis H0: Two samples are equal
stats.mannwhitneyu(group_A.sum_gamerounds, group_B.sum_gamerounds)

# ALTERNATE Hypothesis H1: Two samples are different
stats.mannwhitneyu(group_A.sum_gamerounds, group_B.sum_gamerounds, alternative = "greater")
# Out:
# MannwhitneyuResult(statistic=1009027049.5, pvalue=0.02579103985288993)
# MannwhitneyuResult(statistic=1024240272.5, pvalue=0.02579103985288993)

# %% [markdown]
# <mark>__Analsysis Results:__
#
#
# __.__ We have used mann-whitney u test to check the null hypothesis, whether the two groups are similar or different.
#
# __.__ We have repeated the mann-whitney u test with the same null hypothesis but with the alternate hypothesis being whether the first group is greater than the second group.The results make it clear that the group_A and group_B are statistically different.

# %% [markdown]
# ### Based on significance testing results, if groups A and B are statistically different, which level has more advantage in terms of player retention and number of game rounds played

# %%
#Analyze the 1 day and 7 days retention rate for two different groups using group by function

user_df[["version","retention_7","retention_1"]].groupby("version").agg("mean")
# Out:
#          retention_7  retention_1
# version
# A           0.190165     0.448186
# B           0.182000     0.442283

# %% [markdown]
# <mark>__Analsysis Results:__
#
# __Based on the significance test we can conclude that gate level 30 has higher retention rate.__

# %% [markdown]
# # Using bootstrap resampling, plot the retention rate distribution for both the groups inorder to visualize effect of different version of the game on retention.

# %%
list_1d = []
list_2d = []

for i in range(500):
    boot_mean1 = user_df.sample(frac = 0.7, replace = True).groupby('version')['retention_1'].mean()
    list_1d.append(boot_mean1.values)
    
    boot_mean2 = user_df.sample(frac = 0.7, replace  = True).groupby('version')['retention_7'].mean()
    list_2d.append(boot_mean2.values)
    
# Transforming the list to a DataFrame

list_1d = pd.DataFrame(list_1d, columns = ['gate_30','gate_40'])

list_2d = pd.DataFrame(list_2d, columns = ['gate_30','gate_40'])


# Adding a column with the % difference between the two AB groups
list_1d['diff'] = (list_1d['gate_30'] - list_1d['gate_40']) /  list_1d['gate_30'] * 100
list_2d['diff'] = (list_2d['gate_30'] - list_2d['gate_40']) /  list_2d['gate_30'] * 100

# Ploting the bootstrap % difference
ax = list_1d['diff'].plot(kind = 'kde')
ax.set_xlabel("% difference in means")

ax = list_2d['diff'].plot(kind = 'kde')
ax.set_xlabel("% difference in means")

# Calculating the probability that 7-day retention is greater when the gate is at level 30

prob_1 = (list_1d['diff'] > 0).sum() / len(list_1d)

prob_2 = (list_2d['diff'] > 0).sum() / len(list_2d)

# printing the probability
'{:.1%}'.format(prob_1)
'{:.1%}'.format(prob_2)
# Out:
# Text(0.5, 0, '% difference in means')
# Text(0.5, 0, '% difference in means')
# '91.6%'
# '99.2%'

# %% [markdown]
# __Conclusion:__
# There is strong evidence that 7-days retention is higher when the gate is at level 30 than when it is at level 40.
# __The conclusion is: If we want to keep retention high both for 1-day and for 7-days, then we should not move the gate from level 30 to level 40.__
